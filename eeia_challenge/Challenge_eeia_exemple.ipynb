# %% [markdown]
# # Challenge EEIA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("seaborn")

# %% [markdown]
# # Load data

# %% [markdown]
# Here we define the directory path where the data is stored and will be stored. The files train.csv and test.csv should be in that directory.

# %%
data_path = 'data/'
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
data = pd.read_csv('train.csv',delimiter=';',decimal=',',na_values=["#VALEUR!"],index_col="time")
data = sc.fit_transform(data )
data.index = pd.to_datetime(data.index, format='%d/%m/%Y %H:%M')

test = pd.read_csv('test.csv',delimiter=';',decimal=',',na_values=["#VALEUR!"],index_col="time")
test = sc.transform(test)
test.index = pd.to_datetime(test.index, format='%d/%m/%Y %H:%M')

# %% [markdown]
# The following cell displays the first rows of the dataframe.

# %%
data.head()
# Out:
#                      Amb temp °C  Comp inlet temp °C  amb pressure       HR %  \
# time
# 2022-01-01 00:00:00     2.415345           13.756624   1009.650948  77.891805
# 2022-01-01 00:01:00     2.410162           13.754808   1009.653573  78.010106
# 2022-01-01 00:02:00     2.404979           13.752992   1009.656258  78.128415
# 2022-01-01 00:03:00     2.399796           13.751176   1009.658883  78.246716
# 2022-01-01 00:04:00     2.394613           13.749360   1009.658883  78.365018
#
#                      C/H  Network Frequency (Hz)  \
# time
# 2022-01-01 00:00:00  NaN               44.799709
# 2022-01-01 00:01:00  NaN               44.799660
# 2022-01-01 00:02:00  NaN               44.799614
# 2022-01-01 00:03:00  NaN               44.799565
# 2022-01-01 00:04:00  NaN               44.799519
#
#                      Lower Heating Value (Wh/Nm3)      EOH (h)  DP filtre  \
# time
# 2022-01-01 00:00:00                           NaN  25523.87408   1.566854
# 2022-01-01 00:01:00                           NaN  25523.87408   1.566860
# 2022-01-01 00:02:00                           NaN  25523.87408   1.566866
# 2022-01-01 00:03:00                           NaN  25523.87408   1.566872
# 2022-01-01 00:04:00                           NaN  25523.87408   1.566878
#
#                      CTRL anti givrage     IGV %  Net Power (MW)
# time
# 2022-01-01 00:00:00          -1.289541 -1.575997        8.292017
# 2022-01-01 00:01:00          -1.284832 -1.575923        8.300175
# 2022-01-01 00:02:00          -1.280124 -1.575849        8.308332
# 2022-01-01 00:03:00          -1.275416 -1.575776        8.316489
# 2022-01-01 00:04:00          -1.270708 -1.575702        8.324646

# %%
test.head()
# Out:
#                      Amb temp °C  Comp inlet temp °C  amb pressure       HR %  \
# time
# 2022-04-01 00:00:00    11.097374           18.781390    988.521859  47.755265
# 2022-04-01 00:01:00    11.097563           18.782040    988.528512  48.006848
# 2022-04-01 00:02:00    11.097751           18.779533    988.535226  47.564080
# 2022-04-01 00:03:00    11.097940           18.773055    988.541878  47.522557
# 2022-04-01 00:04:00    11.098129           18.766577    988.548592  47.994592
#
#                           C/H  Network Frequency (Hz)  \
# time
# 2022-04-01 00:00:00  3.284760               44.794838
# 2022-04-01 00:01:00  3.284808               44.794739
# 2022-04-01 00:02:00  3.284855               44.794644
# 2022-04-01 00:03:00  3.284903               44.794544
# 2022-04-01 00:04:00  3.284951               44.794445
#
#                      Lower Heating Value (Wh/Nm3)      EOH (h)  DP filtre  \
# time
# 2022-04-01 00:00:00                   10742.77624  26771.39752   1.475133
# 2022-04-01 00:01:00                   10742.71740  26771.39752   1.550406
# 2022-04-01 00:02:00                   10742.65856  26771.39752   1.538440
# 2022-04-01 00:03:00                   10742.59971  26771.39752   1.434979
# 2022-04-01 00:04:00                   10742.54087  26771.39752   1.491088
#
#                      CTRL anti givrage     IGV %  Net Power (MW)
# time
# 2022-04-01 00:00:00          -7.606029 -2.493310             NaN
# 2022-04-01 00:01:00          -7.592567 -2.493261             NaN
# 2022-04-01 00:02:00          -7.579105 -2.493211             NaN
# 2022-04-01 00:03:00          -7.565642 -2.493162             NaN
# 2022-04-01 00:04:00          -7.561825 -2.493112             NaN

# %% [markdown]
# Getting the shape of the dataframe

# %%
data.shape, test.shape
# Out:
# ((368581, 12), (156960, 12))

# %% [markdown]
# The training set contains 368591 rows andd 12 columns and the test set contains 156960 rows and 12 columns. The test set contains almost half less data than the training set. All the values in the column Net Power (MW) are NaN and should be filled with our model's predictions.
#
# Here are the list of the columns of both dataset :

# %% [markdown]
# <table border="0" padding="0" margin="0">
# <tbody>
# <tr><td>Amb temp (°C)</td><td>Température ambiante</td></tr>
# <tr><td>Comp inlet temp (°C)</td><td>Température entrée compresseur</td></tr>
# <tr><td>amb pressure</td><td>Pression ambiante</td></tr>
# <tr><td>HR %</td><td>%Humidité relative ambiante</td></tr>
# <tr><td>C/H</td><td>Rapport Carbonne/hydrogène du Gaz Nat</td></tr>
# <tr><td>Network Frequency (Hz)</td><td>Fréquence du réseau électrique en Hz</td></tr>
# <tr><td>Lower Heating Value (Wh/Nm3) &nbsp;</td><td>le pouvoir calorifique inférieur du Gaz Nat</td></tr>
# <tr><td>EOH (h)</td><td>Heures d'Opérations Equivalentes </td></tr>
# <tr><td>DP filtre</td><td>Perte de charge au niveau des filtres d'air entrée turbine à gaz</td></tr>
# <tr><td>CTRL anti givrage</td><td>Control de la vanne d'ouverture de l'anti-givre entrée turbine gaz</td></tr>
# <tr><td>IGV %</td><td>% d'ouverture de la valve IGV (Inlet Guide Vanes) afin de controller la charge de la CCGT</td></tr>
# <tr><td>Net Power (MW)</td><td>Production d'électricité NETTE générée par la CCGT</td></tr>
# </tbody>
# </table>

# %% [markdown]
# # Checks

# %% [markdown]
# We check that this data has the exact types we are waiting for.

# %%
assert data.dtypes.equals(pd.Series(dict(zip(data.columns,["float64"]*len(data.columns)))))

assert test.dtypes.equals(pd.Series(dict(zip(test.columns,["float64"]*len(test.columns)))))

# %% [markdown]
# Statistical metrics of the training set such as the minimum, average, standard deviation, maximum, and quantiles are computed below.

# %%
data.head()
# Out:
#                      Amb temp °C  Comp inlet temp °C  amb pressure       HR %  \
# time
# 2022-01-01 00:00:00     2.415345           13.756624   1009.650948  77.891805
# 2022-01-01 00:01:00     2.410162           13.754808   1009.653573  78.010106
# 2022-01-01 00:02:00     2.404979           13.752992   1009.656258  78.128415
# 2022-01-01 00:03:00     2.399796           13.751176   1009.658883  78.246716
# 2022-01-01 00:04:00     2.394613           13.749360   1009.658883  78.365018
#
#                      C/H  Network Frequency (Hz)  \
# time
# 2022-01-01 00:00:00  NaN               44.799709
# 2022-01-01 00:01:00  NaN               44.799660
# 2022-01-01 00:02:00  NaN               44.799614
# 2022-01-01 00:03:00  NaN               44.799565
# 2022-01-01 00:04:00  NaN               44.799519
#
#                      Lower Heating Value (Wh/Nm3)      EOH (h)  DP filtre  \
# time
# 2022-01-01 00:00:00                           NaN  25523.87408   1.566854
# 2022-01-01 00:01:00                           NaN  25523.87408   1.566860
# 2022-01-01 00:02:00                           NaN  25523.87408   1.566866
# 2022-01-01 00:03:00                           NaN  25523.87408   1.566872
# 2022-01-01 00:04:00                           NaN  25523.87408   1.566878
#
#                      CTRL anti givrage     IGV %  Net Power (MW)
# time
# 2022-01-01 00:00:00          -1.289541 -1.575997        8.292017
# 2022-01-01 00:01:00          -1.284832 -1.575923        8.300175
# 2022-01-01 00:02:00          -1.280124 -1.575849        8.308332
# 2022-01-01 00:03:00          -1.275416 -1.575776        8.316489
# 2022-01-01 00:04:00          -1.270708 -1.575702        8.324646

# %%
data.describe()
# Out:
#          Amb temp °C  Comp inlet temp °C   amb pressure           HR %  \
# count  368502.000000       368517.000000  368572.000000  368553.000000
# mean       14.487902           19.880848     992.565003      61.181880
# std         7.576516            7.326484       8.702163      17.264710
# min        -1.092109            1.520982     948.226082       5.427441
# 25%         8.056436           15.194340     987.967126      49.381600
# 50%        14.180040           20.892922     993.306435      65.136250
# 75%        19.532917           25.142531     998.070473      75.373906
# max        42.857579           43.273121    1012.959786      91.678914
#
#                  C/H  Network Frequency (Hz)  Lower Heating Value (Wh/Nm3)  \
# count  368536.000000           368219.000000                 368063.000000
# mean        3.288417               44.976282                  10771.497116
# std         0.015378                1.313475                    108.693864
# min         3.208825               41.268475                    518.654730
# 25%         3.276918               44.776016                  10735.220820
# 50%         3.287632               44.791741                  10763.482070
# 75%         3.301645               46.266140                  10805.505570
# max         3.579373               46.359951                  10989.565000
#
#              EOH (h)      DP filtre  CTRL anti givrage          IGV %  \
# count  367002.000000  368553.000000      368519.000000  368341.000000
# mean    27108.533262       2.726039         -10.856125      21.541416
# std       934.778961       1.806945           7.073100      39.018238
# min     25523.874080       1.227618         -38.742719      -4.989705
# 25%     26594.225637       1.566103         -15.450205      -2.691857
# 50%     27019.401420       1.578827         -10.275179      -2.363789
# 75%     27363.696340       4.621535          -4.644795      42.333016
# max     29407.241270       7.250754           0.997576     203.764500
#
#        Net Power (MW)
# count   368207.000000
# mean       116.847774
# std        169.242280
# min          1.259763
# 25%          8.793495
# 50%          9.631217
# 75%        298.661378
# max        434.143647

# %% [markdown]
# # EDA and first models

# %%
data.isna().sum()
# Out:
# Amb temp °C                       79
# Comp inlet temp °C                64
# amb pressure                       9
# HR %                              28
# C/H                               45
# Network Frequency (Hz)           362
# Lower Heating Value (Wh/Nm3)     518
# EOH (h)                         1579
# DP filtre                         28
# CTRL anti givrage                 62
# IGV %                            240
# Net Power (MW)                   374
# dtype: int64

# %% [markdown]
# There are 3388 NaN values in the dataframe.

# %% [markdown]
# ### Imputing strategy

# %%
from sklearn.impute import SimpleImputer

# %%
# Dropping all the NaN values
# data.dropna(inplace=True)

# Replace the Nans using a given strategy

chosen_strategy = 'median' # "mean" / "constant" / "most_frequent"
for col in data.columns:
    imp_mean = SimpleImputer(missing_values=np.nan, strategy='median')
    data[col] = imp_mean.fit_transform(data[[col]]).squeeze()

# %%
assert (data.isna().sum(axis=0).sum() == 0)

# %% [markdown]
# Let's start by checking all the variables

# %%
fig, ax = plt.subplots(figsize=(20,16),nrows=3, ncols=4)

for i,col in enumerate(data.columns):
    data.head(300)[col].plot(ax=ax[i//4,i%4],title=col)

# %%
data.hist(figsize=(20,16))
# Out:
# array([[<AxesSubplot:title={'center':'Amb temp °C'}>,
#         <AxesSubplot:title={'center':'Comp inlet temp °C'}>,
#         <AxesSubplot:title={'center':'amb pressure'}>],
#        [<AxesSubplot:title={'center':'HR %'}>,
#         <AxesSubplot:title={'center':'C/H'}>,
#         <AxesSubplot:title={'center':'Network Frequency (Hz)'}>],
#        [<AxesSubplot:title={'center':'Lower Heating Value (Wh/Nm3)'}>,
#         <AxesSubplot:title={'center':'EOH (h)'}>,
#         <AxesSubplot:title={'center':'DP filtre'}>],
#        [<AxesSubplot:title={'center':'CTRL anti givrage'}>,
#         <AxesSubplot:title={'center':'IGV %'}>,
#         <AxesSubplot:title={'center':'Net Power (MW)'}>]], dtype=object)

# %% [markdown]
# ## Net Power (MW)

# %%
data["Net Power (MW)"].plot(figsize=(20,12))
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# Let's see if there is any correlation between the Net power (MW) and speed by taking a look at one of them, function of the other.

# %%
x_var = "Amb temp °C"
y_var = "Net Power (MW)"
# data.plot.scatter(x=x_var,y=y_var)

# %%
fig, ax = plt.subplots(figsize=(20,16),nrows=3, ncols=4)

for i,col in enumerate(data.columns):
    data.plot.scatter(x=col,y=y_var,ax=ax[i//4,i%4],title=col)

# %% [markdown]
# The correlation between the variables is not obvious expect for the variables 'DP filtre' and 'IGV %'. Let's take a closer look at the values of the correlations.

# %%
data.corr()
# Out:
#                               Amb temp °C  Comp inlet temp °C  amb pressure  \
# Amb temp °C                      1.000000            0.832129     -0.058992
# Comp inlet temp °C               0.832129            1.000000     -0.091896
# amb pressure                    -0.058992           -0.091896      1.000000
# HR %                            -0.646158           -0.486919     -0.072914
# C/H                             -0.201480           -0.166690     -0.030826
# Network Frequency (Hz)          -0.258454           -0.248427      0.133849
# Lower Heating Value (Wh/Nm3)    -0.096914           -0.079689     -0.074042
# EOH (h)                          0.258548            0.196532      0.176271
# DP filtre                       -0.394582           -0.676609      0.135819
# CTRL anti givrage               -0.989054           -0.818888      0.054058
# IGV %                           -0.406914           -0.713263      0.098018
# Net Power (MW)                  -0.410724           -0.697757      0.121800
#
#                                   HR %       C/H  Network Frequency (Hz)  \
# Amb temp °C                  -0.646158 -0.201480               -0.258454
# Comp inlet temp °C           -0.486919 -0.166690               -0.248427
# amb pressure                 -0.072914 -0.030826                0.133849
# HR %                          1.000000 -0.002462                0.263973
# C/H                          -0.002462  1.000000               -0.352226
# Network Frequency (Hz)        0.263973 -0.352226                1.000000
# Lower Heating Value (Wh/Nm3)  0.012476  0.367359               -0.121671
# EOH (h)                      -0.000718 -0.442525                0.353539
# DP filtre                     0.248770  0.043933                0.273661
# CTRL anti givrage             0.692461  0.159922                0.281066
# IGV %                         0.250508  0.092335                0.229411
# Net Power (MW)                0.243327  0.080399                0.242274
#
#                               Lower Heating Value (Wh/Nm3)   EOH (h)  \
# Amb temp °C                                      -0.096914  0.258548
# Comp inlet temp °C                               -0.079689  0.196532
# amb pressure                                     -0.074042  0.176271
# HR %                                              0.012476 -0.000718
# C/H                                               0.367359 -0.442525
# Network Frequency (Hz)                           -0.121671  0.353539
# Lower Heating Value (Wh/Nm3)                      1.000000 -0.192584
# EOH (h)                                          -0.192584  1.000000
# DP filtre                                         0.019890  0.122325
# CTRL anti givrage                                 0.077475 -0.219787
# IGV %                                             0.043240  0.032371
# Net Power (MW)                                    0.036285  0.061264
#
#                               DP filtre  CTRL anti givrage     IGV %  \
# Amb temp °C                   -0.394582          -0.989054 -0.406914
# Comp inlet temp °C            -0.676609          -0.818888 -0.713263
# amb pressure                   0.135819           0.054058  0.098018
# HR %                           0.248770           0.692461  0.250508
# C/H                            0.043933           0.159922  0.092335
# Network Frequency (Hz)         0.273661           0.281066  0.229411
# Lower Heating Value (Wh/Nm3)   0.019890           0.077475  0.043240
# EOH (h)                        0.122325          -0.219787  0.032371
# DP filtre                      1.000000           0.387459  0.965999
# CTRL anti givrage              0.387459           1.000000  0.396115
# IGV %                          0.965999           0.396115  1.000000
# Net Power (MW)                 0.991804           0.399547  0.971723
#
#                               Net Power (MW)
# Amb temp °C                        -0.410724
# Comp inlet temp °C                 -0.697757
# amb pressure                        0.121800
# HR %                                0.243327
# C/H                                 0.080399
# Network Frequency (Hz)              0.242274
# Lower Heating Value (Wh/Nm3)        0.036285
# EOH (h)                             0.061264
# DP filtre                           0.991804
# CTRL anti givrage                   0.399547
# IGV %                               0.971723
# Net Power (MW)                      1.000000

# %%
data.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_a6089_row0_col0, #T_a6089_row1_col1, #T_a6089_row2_col2, #T_a6089_row3_col3, #T_a6089_row4_col4, #T_a6089_row5_col5, #T_a6089_row6_col6, #T_a6089_row7_col7, #T_a6089_row8_col8, #T_a6089_row9_col9, #T_a6089_row10_col10, #T_a6089_row11_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a6089_row0_col1 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_a6089_row0_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_a6089_row0_col3, #T_a6089_row0_col9, #T_a6089_row1_col2, #T_a6089_row1_col8, #T_a6089_row1_col10, #T_a6089_row1_col11, #T_a6089_row4_col5, #T_a6089_row4_col7, #T_a6089_row7_col4, #T_a6089_row7_col6, #T_a6089_row9_col0, #T_a6089_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a6089_row0_col4 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_a6089_row0_col5, #T_a6089_row11_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_a6089_row0_col6, #T_a6089_row8_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_a6089_row0_col7, #T_a6089_row2_col8 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_a6089_row0_col8, #T_a6089_row0_col11, #T_a6089_row6_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_a6089_row0_col10, #T_a6089_row8_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_a6089_row1_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_a6089_row1_col3, #T_a6089_row1_col6 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_a6089_row1_col4 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_a6089_row1_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_a6089_row1_col7, #T_a6089_row6_col10 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_a6089_row1_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a6089_row2_col0, #T_a6089_row9_col5 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_a6089_row2_col1, #T_a6089_row6_col3 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_a6089_row2_col3, #T_a6089_row11_col7 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_a6089_row2_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_a6089_row2_col5, #T_a6089_row11_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_a6089_row2_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_a6089_row2_col7 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_a6089_row2_col9 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_a6089_row2_col10, #T_a6089_row7_col8 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_a6089_row2_col11 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_a6089_row3_col0, #T_a6089_row3_col6, #T_a6089_row6_col7, #T_a6089_row10_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_a6089_row3_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_a6089_row3_col2, #T_a6089_row6_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a6089_row3_col4, #T_a6089_row3_col7 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_a6089_row3_col5 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_a6089_row3_col8, #T_a6089_row3_col11, #T_a6089_row5_col3, #T_a6089_row5_col7, #T_a6089_row5_col11 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_a6089_row3_col9 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_a6089_row3_col10 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_a6089_row4_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_a6089_row4_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_a6089_row4_col2, #T_a6089_row10_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a6089_row4_col3, #T_a6089_row7_col3, #T_a6089_row8_col7 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_a6089_row4_col6, #T_a6089_row4_col10 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_a6089_row4_col8, #T_a6089_row6_col11, #T_a6089_row10_col5 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_a6089_row4_col9 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_a6089_row4_col11 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_a6089_row5_col0, #T_a6089_row10_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_a6089_row5_col1 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_a6089_row5_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_a6089_row5_col4 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_a6089_row5_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_a6089_row5_col8 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_a6089_row5_col9 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_a6089_row5_col10 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_a6089_row6_col0, #T_a6089_row7_col11 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_a6089_row6_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_a6089_row6_col4 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_a6089_row6_col8, #T_a6089_row9_col4 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_a6089_row6_col9 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_a6089_row7_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_a6089_row7_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_a6089_row7_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_a6089_row7_col5 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_a6089_row7_col9 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_a6089_row7_col10 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_a6089_row8_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_a6089_row8_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_a6089_row8_col3, #T_a6089_row10_col3 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_a6089_row8_col4 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_a6089_row8_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a6089_row8_col9 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_a6089_row8_col10, #T_a6089_row10_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_a6089_row8_col11, #T_a6089_row11_col8 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_a6089_row9_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_a6089_row9_col3 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_a6089_row9_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_a6089_row9_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_a6089_row9_col8 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_a6089_row9_col10, #T_a6089_row9_col11 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_a6089_row10_col0, #T_a6089_row11_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_a6089_row10_col6, #T_a6089_row11_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_a6089_row10_col7 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_a6089_row10_col9, #T_a6089_row11_col9 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_a6089_row10_col11, #T_a6089_row11_col10 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_a6089_row11_col3 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_a6089_row11_col5 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_a6089_row11_col6 {
#   background-color: #dddbec;
#   color: #000000;
# }
# </style>
# <table id="T_a6089">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6089_level0_col0" class="col_heading level0 col0" >Amb temp °C</th>
#       <th id="T_a6089_level0_col1" class="col_heading level0 col1" >Comp inlet temp °C</th>
#       <th id="T_a6089_level0_col2" class="col_heading level0 col2" >amb pressure</th>
#       <th id="T_a6089_level0_col3" class="col_heading level0 col3" >HR %</th>
#       <th id="T_a6089_level0_col4" class="col_heading level0 col4" >C/H</th>
#       <th id="T_a6089_level0_col5" class="col_heading level0 col5" >Network Frequency (Hz)</th>
#       <th id="T_a6089_level0_col6" class="col_heading level0 col6" >Lower Heating Value (Wh/Nm3)</th>
#       <th id="T_a6089_level0_col7" class="col_heading level0 col7" >EOH (h)</th>
#       <th id="T_a6089_level0_col8" class="col_heading level0 col8" >DP filtre</th>
#       <th id="T_a6089_lev

# %% [markdown]
# 'DP filtre' and 'IGV %' are highly correlated with the target variable.

# %% [markdown]
# For a sample, the correlation is defined by :

# %% [markdown]
# $$
# \frac{\sum \limits _{i=1} ^{n} (x_{i} - \bar x) (y_{i} - \bar y)}{\sqrt{\sum \limits _{i=1} ^{n}(x_{i} - \bar x)^{2}}\sqrt{\sum \limits _{i=1} ^{n}(y_{i} - \bar y)^{2}}}
# $$

# %% [markdown]
# What is important to recall is that it is comprised in the range $[-1, 1]$ and : <br>
#     - it is equal to 1 if the two variables are exactly the same <br>
#     - it is equal to -1 if the two variables are the exact opposite <br>
#     - when it is equal to 0, the two variables have nothing in common : they are independent one from the other, for example this could be the value of the bitcoin and the average wind speed in south korea, we know these two have nothing in common.<br>
#     - when it is > 0, the two variables are positively correlated, this means that on average, when one goes up, the other goes up too.<br>
#     - when it is < 0, the two variables are negatively correlated, this means that on average, when one goes up, the other goes down.<br>

# %% [markdown]
# #### EDA ideas
#
# - features selection: drop useless variables? why? how?
# - handle the nan values differently
# - create new variables ?

# %% [markdown]
# ## Modeling

# %% [markdown]
# Based on this first EDA, a very simple model we can try to predict our sample is to try a linear model :

# %% [markdown]
# In order to do so, we import some libraries that will be useful.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# We now cut our dataframe in two : one dataframe will be used for training, and the other one will be used to estimate what is the value of this first model we have made.
# For this, why do we not directly use the test set ? The reason is that for the test set, we do not know the exact value of the power measurement.

# %%
X = data.drop(columns="Net Power (MW)")
y = data["Net Power (MW)"]

print(X.shape, y.shape)
# Out:
# (368581, 11) (368581,)

# %%
X_train, X_eval, y_train, y_eval = train_test_split(X, y,test_size=0.2, shuffle=True,random_state=0)

# %%
def evaluate_model(model):
    print("Model name: ", type(model).__name__)
    print("Model parameters: ", model.get_params())

    # Printing model accuracy
    model_train_mae = mean_absolute_error(y_train,model.predict(X_train))
    model_test_mae = mean_absolute_error(y_eval,model.predict(X_eval))

    print("Model Mean Absolute error on the train set : %.2f" % model_train_mae)
    print("Model Mean Absolute error on the test set : %.2f" % model_test_mae)

# %%
model =LinearRegression()
model.fit(X_train, y_train)
evaluate_model(model)
# Out:
# Model name:  LinearRegression
# Model parameters:  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False, 'positive': False}
# Model Mean Absolute error on the train set : 10.27
# Model Mean Absolute error on the test set : 10.26

# %% [markdown]
# Nice ! We have our first model and it gives an error of 10.27 !..
#
# Now wait, what is the value of that first model ? How can we know if 10.27 is actually a good error ? Well for this, a very neat way to be able to know if our model is worth anything is to compare it to a naive model. A naive model can be for example to predict everytime the same value, whatever the conditions. One of these naive model we have at hand would be to predict the mean value of the wind power in the train set. Let's see what would this model give.

# %% [markdown]
# #### LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model0 = LogisticRegression()
model0.fit(X_train, y_train)
evaluate_model(model0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 model0 = LogisticRegression()
# ----> 2 model0.fit(X_train, y_train)
#       3 evaluate_model(model0)
#
# File c:\users\hp\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:1347, in LogisticRegression.fit(self, X, y, sample_weight)
#    1342     _dtype = [np.float64, np.float32]
#    1344 X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                            order="C",
#    1346                            accept_large_sparse=solver != 'liblinear')
# -> 1347 check_classification_targets(y)
#    1348 self.classes_ = np.unique(y)
#    1350 multi_class = _check_multi_class(self.multi_class, solver,
#    1351                                  len(self.classes_))
#
# File c:\users\hp\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\multiclass.py:183, in check_classification_targets(y)
#     180 y_type = type_of_target(y)
#     181 if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                   'multilabel-indicator', 'multilabel-sequences']:
# --> 183     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model1 =KNeighborsRegressor(n_neighbors=2)
model1.fit(X_train, y_train)
evaluate_model(model1)
# Out:
# Model name:  KNeighborsRegressor
# Model parameters:  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 2, 'p': 2, 'weights': 'uniform'}
# Model Mean Absolute error on the train set : 0.34
# Model Mean Absolute error on the test set : 0.60

# %% [markdown]
# ## MLP

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)
from sklearn.neural_network import MLPRegressor

# %%
model2 =MLPRegressor(solver='lbfgs',alpha=1e-5,hidden_layer_sizes=(10,), random_state=0,activation = 'relu',max_iter = 3000,early_stopping=True)
model2.fit(X_train, y_train)
evaluate_model(model2)
# Out:
# Model name:  MLPRegressor
# Model parameters:  {'activation': 'relu', 'alpha': 1e-05, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (10,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 3000, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'lbfgs', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# Model Mean Absolute error on the train set : 20.93
# Model Mean Absolute error on the test set : 20.63

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model3 =RandomForestRegressor(n_estimators=100, random_state=0)
model3.fit(X_train, y_train)
evaluate_model(model3)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVR ,NuSVR ,LinearSVR

# %%
model4 = SVR(kernel = 'linear' , gamma = 'auto')#LinearRegression()
model4.fit(X_train, y_train)
evaluate_model(model4)

# %%
model5 = NuSVR( kernel = 'linear', gamma = 'auto', C = 1.0, nu = 0.1)#LinearRegression()
model5.fit(X_train, y_train)
evaluate_model(model5)

# %%
model = LinearSVR( dual = False, random_state = 0, loss = 'squared_epsilon_insensitive', tol = 1e-5)#LinearRegression()
model.fit(X_train, y_train)
evaluate_model(model)

# %% [markdown]
# ## Dummy

# %%
from sklearn.dummy import DummyRegressor

# %%
dummy_model = DummyRegressor(strategy='mean')
dummy_model.fit(X_train, y_train)

evaluate_model(dummy_model)
# Out:
# Model name:  DummyRegressor
# Model parameters:  {'constant': None, 'quantile': None, 'strategy': 'mean'}
# Model Mean Absolute error on the train set : 150.28
# Model Mean Absolute error on the test set : 150.73

# %%
dummy_model = DummyRegressor(strategy='median')
dummy_model.fit(X_train, y_train)

evaluate_model(dummy_model)
# Out:
# Model name:  DummyRegressor
# Model parameters:  {'constant': None, 'quantile': None, 'strategy': 'median'}
# Model Mean Absolute error on the train set : 107.94
# Model Mean Absolute error on the test set : 108.37

# %% [markdown]
# Yes ! Good news, our model did really learn something good ! We are a lot better than the 'mean' or 'median' model, around 10 times better, based on this metric.

# %% [markdown]
# # Next steps Modeling

# %% [markdown]
# We have already seen first models above : the linear model with all the variables , and two naive models (median, and mean). It will be your job from now on to determine the best model, but let's already take a look at one classic model that data scientists usually try on for nearly any subject : Random Forest.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_jobs=-1,max_samples=200)
rf_model.fit(X_train, y_train)
evaluate_model(rf_model)
# Out:
# Model name:  RandomForestRegressor
# Model parameters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'mse', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': 200, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Model Mean Absolute error on the train set : 3.30
# Model Mean Absolute error on the test set : 3.26

# %% [markdown]
# Random Forest does better than the linear model.

# %%
from sklearn.model_selection import cross_val_score, KFold

# %% [markdown]
# ## Cross Validation

# %%
cv_rf_model = RandomForestRegressor(n_jobs=-1,max_samples=200)

# %%
cv_rf_model1 = KNeighborsRegressor(n_neighbors=2)

# %%
cv_scores = []
for i in range(2, 11):
    kfold = KFold(n_splits=i)
    scores = cross_val_score(cv_rf_model1, X, y,scoring="neg_mean_absolute_error", cv=kfold)
    cv_scores.append(-scores.mean())

best_cv = cv_scores.index(max(cv_scores)) + 2
print(f"The best cross-validation split is {best_cv}-fold with a mean score of {max(cv_scores)}")
# Out:
# The best cross-validation split is 2-fold with a mean score of 98.27924280729806

# %%
X_train, X_eval, y_train, y_eval = train_test_split(X, y,test_size=1/best_cv, shuffle=True,random_state=0)

# %%
cv_rf_model1.fit(X_train, y_train)
evaluate_model(cv_rf_model1)
# Out:
# Model name:  KNeighborsRegressor
# Model parameters:  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 2, 'p': 2, 'weights': 'uniform'}
# Model Mean Absolute error on the train set : 0.39
# Model Mean Absolute error on the test set : 0.74

# %% [markdown]
# ### Modeling ideas
#
# - Try different parameters for the models ?
# - Try new models ?
# - Tune parameters ?

# %% [markdown]
# # Predictions on test set

# %% [markdown]
# Now our model is fit, we can pass on to the predictions.
#
# _Note: be careful when generating your submission file. Indeed, it needs to be a csv file with ";" as separator._

# %% [markdown]
# ##### KNN without CV

# %%
selected_model =model2#rf_model #cv_rf_model

# %%
X_test = test.drop(columns="Net Power (MW)")

df_predictions = pd.DataFrame({
    'time': test.index,
    'Net Power (MW)': selected_model.predict(X_test),
})

df_predictions.to_csv('MLPpredictions.csv', date_format='%d/%m/%Y %H:%M',index=False, sep=';')
df_predictions.head()
# Out:
#                  time  Net Power (MW)
# 0 2022-04-01 00:00:00       20.243326
# 1 2022-04-01 00:01:00       20.224486
# 2 2022-04-01 00:02:00       20.315069
# 3 2022-04-01 00:03:00       20.297284
# 4 2022-04-01 00:04:00       20.229314

# %% [markdown]
# ##### KNN With CV

# %%
selected_model1 = cv_rf_model1

# %%
X_test = test.drop(columns="Net Power (MW)")

df_predictions1 = pd.DataFrame({
    'time': test.index,
    'Net Power (MW)': selected_model1.predict(X_test),
})

df_predictions1.to_csv('predictionsCV.csv', date_format='%d/%m/%Y %H:%M',index=False, sep=';')
df_predictions1.head()
# Out:
#                  time  Net Power (MW)
# 0 2022-04-01 00:00:00        8.621075
# 1 2022-04-01 00:01:00        8.621075
# 2 2022-04-01 00:02:00        8.620925
# 3 2022-04-01 00:03:00        8.620925
# 4 2022-04-01 00:04:00        8.621075

# %% [markdown]
# Now it is your turn, what better model can you think of ?
